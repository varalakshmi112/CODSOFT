# %%
import pandas as pd
import numpy as np
import pickle
import matplotlib.pyplot as plt
from scipy import stats
import tensorflow as tf
import seaborn as sns
from pylab import rcParams
from sklearn.model_selection import train_test_split
from keras.models import Model, load_model
from keras.layers import Input, Dense
from keras.callbacks import ModelCheckpoint, TensorBoard
from keras import regularizers

# %matplotlib inline

sns.set(style='whitegrid', palette='muted', font_scale=1.5)

rcParams['figure.figsize'] = 14, 8

RANDOM_SEED = 42
LABELS = ["Normal", "Fraud"]

# %% [markdown]
# **loading the dataset**

# %%
df = pd.read_csv("creditcard.csv")

# %% [markdown]
# EXPLORATION

# %%
df.shape
# Out:
# (19898, 31)

# %%
df.isnull().values.any()
# Out:
# True

# %%
count_classes = pd.value_counts(df['Class'], sort = True)
count_classes.plot(kind = 'bar', rot=0)
plt.title("Transaction class distribution")
plt.xticks(range(2), LABELS)
plt.xlabel("Class")
plt.ylabel("Frequency");

# %% [markdown]
# We have a highly imbalanced dataset on our hands. Normal transactions overwhelm the fraudulent ones by a large margin. Let's look at the two types of transactions:

# %%
frauds = df[df.Class == 1]
normal = df[df.Class == 0]

# %%
frauds.shape
# Out:
# (85, 31)

# %%
normal.shape
# Out:
# (19812, 31)

# %%
frauds.Amount.describe()
# Out:
# count      85.000000
# mean       93.869647
# std       261.736641
# min         0.000000
# 25%         1.000000
# 50%         1.000000
# 75%        99.990000
# max      1809.680000
# Name: Amount, dtype: float64

# %%
normal.Amount.describe()
# Out:
# count    19812.000000
# mean        70.169855
# std        205.091118
# min          0.000000
# 25%          5.900000
# 50%         16.070000
# 75%         59.950000
# max       7879.420000
# Name: Amount, dtype: float64

# %% [markdown]
# GRAPHICAL REPRESNTATION

# %%
f, (ax1, ax2) = plt.subplots(2, 1, sharex=True)
f.suptitle('Amount per transaction by class')

bins = 50

ax1.hist(frauds.Amount, bins = bins)
ax1.set_title('Fraud')

ax2.hist(normal.Amount, bins = bins)
ax2.set_title('Normal')

plt.xlabel('Amount ($)')
plt.ylabel('Number of Transactions')
plt.xlim((0, 20000))
plt.yscale('log')
plt.show();

# %%
f, (ax1, ax2) = plt.subplots(2, 1, sharex=True)
f.suptitle('Time of transaction vs Amount by class')

ax1.scatter(frauds.Time, frauds.Amount)
ax1.set_title('Fraud')

ax2.scatter(normal.Time, normal.Amount)
ax2.set_title('Normal')

plt.xlabel('Time (in Seconds)')
plt.ylabel('Amount')
plt.show()

# %% [markdown]
# PREPARING THE DATA

# %%
from sklearn.preprocessing import StandardScaler

data = df.drop(['Time'], axis=1)

data['Amount'] = StandardScaler().fit_transform(data['Amount'].values.reshape(-1, 1))

# %%
X_train, X_test = train_test_split(data, test_size=0.2, random_state=RANDOM_SEED)
X_train = X_train[X_train.Class == 0]
X_train = X_train.drop(['Class'], axis=1)

y_test = X_test['Class']
X_test = X_test.drop(['Class'], axis=1)

X_train = X_train.values
X_test = X_test.values

# %%
X_train.shape
# Out:
# (15846, 29)

# %% [markdown]
# BUILDING THE MODEL

# %%
input_dim = X_train.shape[1]
encoding_dim = 14

# %%
input_layer = Input(shape=(input_dim, ))

encoder = Dense(encoding_dim, activation="tanh",
                activity_regularizer=regularizers.l1(10e-5))(input_layer)
encoder = Dense(int(encoding_dim / 2), activation="relu")(encoder)

decoder = Dense(int(encoding_dim / 2), activation='tanh')(encoder)
decoder = Dense(input_dim, activation='relu')(decoder)

autoencoder = Model(inputs=input_layer, outputs=decoder)

# %% [markdown]
# Let's train our model for 100 epochs with a batch size of 32 samples and save the best performing model to a file. The ModelCheckpoint provided by Keras is really handy for such tasks. Additionally, the training progress will be exported in a format that TensorBoard understands.

# %%
nb_epoch = 100
batch_size = 32

autoencoder.compile(optimizer='adam',
                    loss='mean_squared_error',
                    metrics=['accuracy'])

checkpointer = ModelCheckpoint(filepath="model.h5",
                               verbose=0,
                               save_best_only=True)
tensorboard = TensorBoard(log_dir='./logs',
                          histogram_freq=0,
                          write_graph=True,
                          write_images=True)

history = autoencoder.fit(X_train, X_train,
                    epochs=nb_epoch,
                    batch_size=batch_size,
                    shuffle=True,
                    validation_data=(X_test, X_test),
                    verbose=1,
                    callbacks=[checkpointer, tensorboard]).history
# Out:
# Epoch 1/100
# 496/496 [==============================] - 4s 4ms/step - loss: 1.0400 - accuracy: 0.2635 - val_loss: 1.1671 - val_accuracy: 0.4113
# Epoch 2/100
#  61/496 [==>...........................] - ETA: 1s - loss: 0.9542 - accuracy: 0.4226
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 496/496 [==============================] - 2s 4ms/step - loss: 0.9031 - accuracy: 0.4417 - val_loss: 1.0714 - val_accuracy: 0.5186
# Epoch 3/100
# 496/496 [==============================] - 2s 3ms/step - loss: 0.8518 - accuracy: 0.5513 - val_loss: 1.0418 - val_accuracy: 0.5719
# Epoch 4/100
# 496/496 [==============================] - 2s 3ms/step - loss: 0.8302 - accuracy: 0.6002 - val_loss: 1.0252 - val_accuracy: 0.6126
# Epoch 5/100
# 496/496 [==============================] - 1s 3ms/step - loss: 0.8179 - accuracy: 0.6205 - val_loss: 1.0138 - val_accuracy: 0.6261
# Epoch 6/100
# 496/496 [==============================] - 2s 4ms/step - loss: 0.8100 - accuracy: 0.6299 - val_loss: 1.0061 - val_accuracy: 0.6367
# Epoch 7/100
# 496/496 [==============================] - 3s 6ms/step - loss: 0.8040 - accuracy: 0.6362 - val_loss: 0.9993 - val_accuracy: 0.6417
# Epoch 8/100
# 496/496 [==============================] - 2s 3ms/step - loss: 0.7993 - accuracy: 0.6424 - val_loss: 0.9945 - val_accuracy: 0.6490
# Epoch 9/100
# 496/496 [==============================] - 2s 3ms/step - loss: 0.7952 - accuracy: 0.6458 - val_loss: 0.9898 - val_accuracy: 0.6492
# Epoch 10/100
# 496/496 [==============================] - 2s 3ms/step - loss: 0.7915 - accuracy: 0.6515 - val_loss: 0.9859 - val_accuracy: 0.6525
# Epoch 11/100
# 496/496 [==============================] - 1s 3ms/step - loss: 0.7879 - accuracy: 0.6543 - val_loss: 0.9816 - val_accuracy: 0.6618
# Epoch 12/100
# 496/496 [==============================] - 2s 3ms/step - loss: 0.7850 - accuracy: 0.6609 - val_loss: 0.9776 - val_accuracy: 0.6638
# Epoch 13/100
# 496/496 [==============================] - 2s 3ms/step - loss: 0.7810 - accuracy: 0.6659 - val_loss: 0.9736 - val_accuracy: 0.6721
# Epoch 14/100
# 496/496 [==============================] - 2s 4ms/step - loss: 0.7772 - accuracy: 0.6744 - val_loss: 0.9685 - val_accuracy: 0.6791
# Epoch 15/100
# 496/496 [==============================] - 2s 5ms/step - loss: 0.7728 - accuracy: 0.6838 - val_loss: 0.9631 - val_accuracy: 0.6842
# Epoch 16/100
# 496/496 [==============================] - 1s 3ms/step - loss: 0.7676 - accuracy: 0.6968 - val_loss: 0.9571 - val_accuracy: 0.6992
# Epoch 17/100
# 496/496 [==============================] - 1s 3ms/step - loss: 0.7627 - accuracy: 0.7116 - val_loss: 0.9512 - val_accuracy: 0.7108
# Epoch 18/100
# 496/496 [==============================] - 1s 3ms/step - loss: 0.7585 - accuracy: 0.7161 - val_loss: 0.9459 - val_accuracy: 0.7118
# Epoch 19/100
# 496/496 [==============================] - 1s 3ms/step - loss: 0.7554 - accuracy: 0.7243 - val_loss: 0.9449 - val_accuracy: 0.7244
# Epoch 20/100
# 496/496 [==============================] - 2s 3ms/step - loss: 0.7531 - accuracy: 0.7308 - val_loss: 0.9396 - val_accuracy: 0.7244
# Epoch 21/100
# 496/496 [==============================] - 1s 3ms/step - loss: 0.7501 - accuracy: 0.7348 - val_loss: 0.9371 - val_accuracy: 0.7397
# Epoch 22/100
# 496/496 [==============================] - 2s 3ms/step - loss: 0.7482 - accuracy: 0.7389 - val_loss: 0.9337 - val_accuracy: 0.7397
# Epoch 23/100
# 496/496 [==============================] - 2s 5ms/step - loss: 0.7456 - accuracy: 0.7410 - val_loss: 0.9310 - val_accuracy: 0.7372
# Epoch 24/100
# 496/496 [==============================] - 2s 4ms/step - loss: 0.7450 - accuracy: 0.7437 - val_loss: 0.9295 - val_accuracy: 0.7382
# Epoch 25/100
# 496/496 [==============================] - 1s 3ms/step - loss: 0.7429 - accuracy: 0.7485 - val_loss: 0.9290 - val_accuracy: 0.7450
# Epoch 26/100
# 496/496 [==============================] - 2s 3ms/step - loss: 0.7416 - accuracy: 0.7497 - val_loss: 0.9261 - val_accuracy: 0.7538
# Epoch 27/100
# 496/496 [==============================] - 3s 5ms/step - loss: 0.7399 - accuracy: 0.7503 - val_loss: 0.9244 - val_accuracy: 0.7558
# Epoch 28/100
# 496/496 [==============================] - 2s 3ms/step - loss: 0.7390 - accuracy: 0.7519 - val_loss: 0.9228 - val_accuracy: 0.7520
# Epoch 29/100
# 496/496 [==============================] - 3s 6ms/step - loss: 0.7379 - accuracy: 0.7561 - val_loss: 0.9222 - val_accuracy: 0.7535
# Epoch 30/100
# 496/496 [==============================] - 2s 5ms/step - loss: 0.7370 - accuracy: 0.7529 - val_loss: 0.9204 - val_accuracy: 0.7477
# Epoch 31/100
# 496/496 [==============================] - 2s 4ms/step - loss: 0.7364 - accuracy: 0.7554 - val_loss: 0.9185 - val_accuracy: 0.7646
# Epoch 32/100
# 496/496 [==============================] - 1s 3ms/step - loss: 0.7358 - accuracy: 0.7526 - val_loss: 0.9178 - val_accuracy: 0.7641
# Epoch 33/100
# 496/496 [==============================] - 1s 3ms/step - loss: 0.7349 - accuracy: 0.7525 - val_loss: 0.9178 - val_accuracy: 0.7555
# Epoch 34/100
# 496/496 [==============================] - 1s 3ms/step - loss: 0.7342 - accuracy: 0.7548 - val_loss: 0.9165 - val_accuracy: 0.7590
# Epoch 35/100
# 496/496 [==============================] - 1s 3ms/step - loss: 0.7338 - accuracy: 0.7554 - val_loss: 0.9155 - val_accuracy: 0.7535
# Epoch 36/100
# 496/496 [==============================] - 2s 3ms/step - loss: 0.7330 - accuracy: 0.7555 - val_loss: 0.9151 - val_accuracy: 0.7696
# Epoch 37/100
# 496/496 [==============================] - 1s 3ms/step - loss: 0.7330 - accuracy: 0.7567 - val_loss: 0.9170 - val_accuracy: 0.7585
# Epoch 38/100
# 496/496 [==============================] - 2s 3ms/step - loss: 0.7329 - accuracy: 0.7544 - val_loss: 0.9123 - val_accuracy: 0.7613
# Epoch 39/100
# 496/496 [==============================] - 2s 4ms/step - loss: 0.7316 - accuracy: 0.7601 - val_loss: 0.9117 - val_accuracy: 0.7538
# Epoch 40/100
# 496/496 [==============================] - 3s 6ms/step - loss: 0.7314 - accuracy: 0.7592 - val_loss: 0.9187 - val_accuracy: 0.7535
# Epoch 41/100
# 496/496 [==============================] - 2s 3ms/step - loss: 0.7314 - accuracy: 0.7563 - val_loss: 0.9107 - val_accuracy: 0.7505
# Epoch 42/100
# 496/496 [==============================] - 2s 3ms/step - loss: 0.7317 - accuracy: 0.7547 - val_loss: 0.9131 - val_accuracy: 0.7472
# Epoch 43/100
# 496/496 [==============================] - 2s 5ms/step - loss: 0.7302 - accuracy: 0.7591 - val_loss: 0.9090 - val_accuracy: 0.7643
# Epoch 44/100
# 496/496 [==============================] - 2s 4ms/step - loss: 0.7295 - accuracy: 0.7587 - val_loss: 0.9091 - val_accuracy: 0.7595
# Epoch 45/100
# 496/496 [==============================] - 2s 4ms/step - loss: 0.7294 - accuracy: 0.7587 - val_loss: 0.9089 - val_accuracy: 0.7651
# Epoch 46/100
# 496/496 [==============================] - 4s 8ms/step - loss: 0.7292 - accuracy: 0.7607 - val_loss: 0.9076 - val_accuracy: 0.7691
# Epoch 47/100
# 496/496 [==============================] - 3s 5ms/step - loss: 0.7292 - accuracy: 0.7592 - val_loss: 0.9099 - val_accuracy: 0.7563
# Epoch 48/100
# 496/496 [==============================] - 1s 3ms/step - loss: 0.7289 - accuracy: 0.7613 - val_loss: 0.9073 - val_accuracy: 0.7616
# Epoch 49/100
# 496/496 [==============================] - 1s 3ms/step - loss: 0.7285 - accuracy: 0.7613 - val_loss: 0.9067 - val_accuracy: 0.7585
# Epoch 50/100
# 496/496 [==============================] - 2s 4ms/step - loss: 0.7287 - accuracy: 0.7587 - val_loss: 0.9066 - val_accuracy: 0.7623
# Epoch 51/100
# 496/496 [==============================] - 2s 4ms/step - loss: 0.7281 - accuracy: 0.7610 - val_loss: 0.9078 - val_accuracy: 0.7563
# Epoch 52/100
# 496/496 [==============================] - 3s 5ms/step - loss: 0.7283 - accuracy: 0.7609 - val_loss: 0.9074 - val_accuracy: 0.7555
# Epoch 53/100
# 496/496 [==============================] - 2s 5ms/step - loss: 0.7280 - accuracy: 0.7604 - val_loss: 0.9094 - val_accuracy: 0.7520
# Epoch 54/100
# 496/496 [==============================] - 2s 3ms/step - loss: 0.7280 - accuracy: 0.7612 - val_loss: 0.9056 - val_accuracy: 0.7661
# Epoch 55/100
# 496/496 [==============================] - 2s 3ms/step - loss: 0.7275 - accuracy: 0.7587 - val_loss: 0.9054 - val_accuracy: 0.7653
# Epoch 56/100
# 496/496 [==============================] - 2s 3ms/step - loss: 0.7268 - accuracy: 0.7611 - val_loss: 0.9049 - val_accuracy: 0.7666
# Epoch 57/100
# 496/496 [==============================] - 2s 4ms/step - loss: 0.7265 - accuracy: 0.7638 - val_loss: 0.9047 - val_accuracy: 0.7683
# Epoch 58/100
# 496/496 [==============================] - 2s 4ms/step - loss: 0.7265 - accuracy: 0.7608 - val_loss: 0.9044 - val_accuracy: 0.7613
# Epoch 59/100
# 496/496 [==============================] - 3s 5ms/step - loss: 0.7265 - accuracy: 0.7616 - val_loss: 0.9036 - val_accuracy: 0.7568
# Epoch 60/100
# 496/496 [==============================] - 5s 10ms/step - loss: 0.7263 - accuracy: 0.7601 - val_loss: 0.9036 - val_accuracy: 0.7648
# Epoch 61/100
# 496/496 [==============================] - 4s 8ms/step - loss: 0.7259 - accuracy: 0.7619 - val_loss: 0.9040 - val_accuracy: 0.7590
# Epoch 62/100
# 496/496 [==============================] - 3s 6ms/step - loss: 0.7259 - accuracy: 0.7637 - val_loss: 0.9035 - val_accuracy: 0.7515
# Epoch 63/100
# 496/496 [==============================] - 8s 16ms/step - loss: 0.7257 - accuracy: 0.7602 - val_loss: 0.9040 - val_accuracy: 0.7578
# Epoch 64/100
# 496/496 [==============================] - 4s 9ms/step - loss: 0.7263 - accuracy: 0.7620 - val_loss: 0.9035 - val_accuracy: 0.7608
# Epoch 65/100
# 496/496 [==============================] - 3s 5ms/step - loss: 0.7254 - accuracy: 0.7621 - val_loss: 0.9029 - val_accuracy: 0.7608
# Epoch 66/100
# 496/496 [==============================] - 2s 3ms/step - loss: 0.7248 - accuracy: 0.7631 - val_loss: 0.9026 - val_accuracy: 0.7525
# Epoch 67/100
# 496/496 [==============================] - 2s 4ms/step - loss: 0.7250 - accuracy: 0.7602 - val_loss: 0.9021 - val_accuracy: 0.7598
# Epoch 68/100
# 496/496 [==============================] - 2s 5ms/step - loss: 0.7252 - accuracy: 0.7580 - val_loss: 0.9014 - val_accuracy: 0.7616
# Epoch 69/100
# 496/496 [==============================] - 2s 3ms/step - loss: 0.7249 - accuracy: 0.7605 - val_loss: 0.9022 - val_accuracy: 0.7593
# Epoch 70/100
# 496/496 [==============================] - 2s 4ms/step - loss: 0.7251 - accuracy: 0.7599 - val_loss: 0.9006 - val_accuracy: 0.7666
# Epoch 71/100
# 496/496 [==============================] - 2s 5ms/step - loss: 0.7251 - accuracy: 0.7599 - val_loss: 0.9002 - val_accuracy: 0.7583
# Epoch 72/100
# 496/496 [==============================] - 2s 3ms/step - loss: 0.7249 - accuracy: 0.7582 - val_loss: 0.9005 - val_accuracy: 0.7608
# Epoch 73/100
# 496/496 [==============================] - 2s 3ms/step - loss: 0.7245 - accuracy: 0.7614 - val_loss: 0.9021 - val_accuracy: 0.7508
# Epoch 74/100
# 496/496 [==============================] - 2s 4ms/step - loss: 0.7246 - accuracy: 0.7609 - val_loss: 0.9002 - val_accuracy: 0.7608
# Epoch 75/100
# 496/496 [==============================] - 2s 5ms/step - loss: 0.7239 - accuracy: 0.7569 - val_loss: 0.9010 - val_accuracy: 0.7626
# Epoch 76/100
# 496/496 [==============================] - 2s 4ms/step - loss: 0.7237 - accuracy: 0.7596 - val_loss: 0.9006 - val_accuracy: 0.7510
# Epoch 77/100
# 496/496 [==============================] - 1s 3ms/step - loss: 0.7240 - accuracy: 0.7577 - val_loss: 0.9010 - val_accuracy: 0.7621
# Epoch 78/100
# 496/496 [==============================] - 1s 3ms/step - loss: 0.7238 - accuracy: 0.7592 - val_loss: 0.9002 - val_accuracy: 0.7510
# Epoch 79/100
# 496/496 [==============================] - 1s 3ms/step - loss: 0.7236 - accuracy: 0.7592 - val_loss: 0.8986 - val_accuracy: 0.7568
# Epoch 80/100
# 496/496 [==============================] - 1s 3ms/step - loss: 0.7239 - accuracy: 0.7584 - val_loss: 0.8990 - val_accuracy: 0.7601
# Epoch 81/100
# 496/496 [==============================] - 1s 3ms/step - loss: 0.7231 - accuracy: 0.7626 - val_loss: 0.9046 - val_accuracy: 0.7475
# Epoch 82/100
# 496/496 [==============================] - 1s 3ms/step - loss: 0.7237 - accuracy: 0.7577 - val_loss: 0.8992 - val_accuracy: 0.7568
# Epoch 83/100
# 496/496 [==============================] - 3s 6ms/step - loss: 0.7241 - accuracy: 0.7563 - val_loss: 0.9004 - val_accuracy: 0.7565
# Epoch 84/100
# 496/496 [==============================] - 4s 8ms/step - loss: 0.7233 - accuracy: 0.7571 - val_loss: 0.9011 - val_accuracy: 0.7492
# Epoch 85/100
# 496/496 [==============================] - 4s 7ms/step - loss: 0.7236 - accuracy: 0.7563 - val_loss: 0.8990 - val_accuracy: 0.7530
# Epoch 86/100
# 496/496 [==============================] - 2s 3ms/step - loss: 0.7230 - accuracy: 0.7577 - val_loss: 0.9032 - val_accuracy: 0.7405
# Epoch 87/100
# 496/496 [==============================] - 2s 5ms/step - loss: 0.7232 - accuracy: 0.7594 - val_loss: 0.9007 - val_accuracy: 0.7590
# Epoch 88/100
# 496/496 [==============================] - 2s 3ms/step - loss: 0.7234 - accuracy: 0.7572 - val_loss: 0.8996 - val_accuracy: 0.7553
# Epoch 89/100
# 496/496 [==============================] - 3s 7ms/step - loss: 0.7226 - accuracy: 0.7598 - val_loss: 0.8979 - val_accuracy: 0.7520
# Epoch 90/100
# 496/496 [==============================] - 3s 6ms/step - loss: 0.7233 - accuracy: 0.7582 - val_loss: 0.9018 - val_accuracy: 0.7415
# Epoch 91/100
# 496/496 [==============================] - 2s 4ms/step - loss: 0.7231 - accuracy: 0.7589 - val_loss: 0.8983 - val_accuracy: 0.7510
# Epoch 92/100
# 496/496 [==============================] - 1s 3ms/step - loss: 0.7226 - accuracy: 0.7601 - val_loss: 0.8989 - val_accuracy: 0.7525
# Epoch 93/100
# 496/496 [==============================] - 1s 3ms/step - loss: 0.7225 - accuracy: 0.7598 - val_loss: 0.8971 - val_accuracy: 0.7525
# Epoch 94/100
# 496/496 [==============================] - 1s 3ms/step - loss: 0.7226 - accuracy: 0.7587 - val_loss: 0.9027 - val_accuracy: 0.7379
# Epoch 95/100
# 496/496 [==============================] - 2s 3ms/step - loss: 0.7228 - accuracy: 0.7592 - val_loss: 0.8976 - val_accuracy: 0.7530
# Epoch 96/100
# 496/496 [==============================] - 2s 3ms/step - loss: 0.7221 - accuracy: 0.7583 - val_loss: 0.8978 - val_accuracy: 0.7563
# Epoch 97/100
# 496/496 [==============================] - 2s 5ms/step - loss: 0.7222 - accuracy: 0.7623 - val_loss: 0.8973 - val_accuracy: 0.7601
# Epoch 98/100
# 496/496 [==============================] - 2s 5ms/step - loss: 0.7227 - accuracy: 0.7585 - val_loss: 0.9025 - val_accuracy: 0.7462
# Epoch 99/100
# 496/496 [==============================] - 2s 3ms/step - loss: 0.7240 - accuracy: 0.7571 - val_loss: 0.8976 - val_accuracy: 0.7513
# Epoch 100/100
# 496/496 [==============================] - 2s 5ms/step - loss: 0.7220 - accuracy: 0.7615 - val_loss: 0.9003 - val_accuracy: 0.7430

# %%
autoencoder = load_model('model.h5')

# %% [markdown]
# EVALUATION

# %%
plt.plot(history['loss'])
plt.plot(history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper right');

# %%
predictions = autoencoder.predict(X_test)
# Out:
# 125/125 [==============================] - 0s 1ms/step

# %%
mse = np.mean(np.power(X_test - predictions, 2), axis=1)
error_df = pd.DataFrame({'reconstruction_error': mse,
                        'true_class': y_test})

# %%
error_df.describe()

# %% [markdown]
# RECONSTRUCTION ERROR WITH FRAUD

# %%
fig = plt.figure()
ax = fig.add_subplot(111)
normal_error_df = error_df[(error_df['true_class']== 0) & (error_df['reconstruction_error'] < 10)]
_ = ax.hist(normal_error_df.reconstruction_error.values, bins=10)

# %%
fig = plt.figure()
ax = fig.add_subplot(111)
fraud_error_df = error_df[error_df['true_class'] == 1]
_ = ax.hist(fraud_error_df.reconstruction_error.values, bins=10)

# %%
from sklearn.metrics import (confusion_matrix, precision_recall_curve, auc,
                             roc_curve, recall_score, classification_report, f1_score,
                             precision_recall_fscore_support)

# %%
fpr, tpr, thresholds = roc_curve(error_df.true_class, error_df.reconstruction_error)
roc_auc = auc(fpr, tpr)

plt.title('Receiver Operating Characteristic')
plt.plot(fpr, tpr, label='AUC = %0.4f'% roc_auc)
plt.legend(loc='lower right')
plt.plot([0,1],[0,1],'r--')
plt.xlim([-0.001, 1])
plt.ylim([0, 1.001])
plt.ylabel('True Positive Rate')
plt.xlabel('False Positive Rate')
plt.show();

# %% [markdown]
# Precision vs Recall

# %% [markdown]
# Precision and recall are defined as follows:
#
#
#
#
#
# Let's take an example from Information Retrieval in order to better understand what precision and recall are. Precision measures the relevancy of obtained results. Recall, on the other hand, measures how many relevant results are returned. Both values can take values between 0 and 1. You would love to have a system with both values being equal to 1.
#
# Let's return to our example from Information Retrieval. High recall but low precision means many results, most of which has low or no relevancy. When precision is high but recall is low we have the opposite - few returned results with very high relevancy. Ideally, you would want high precision and high recall - many results with that are highly relevant.

# %%
precision, recall, th = precision_recall_curve(error_df.true_class, error_df.reconstruction_error)
plt.plot(recall, precision, 'b', label='Precision-Recall curve')
plt.title('Recall vs Precision')
plt.xlabel('Recall')
plt.ylabel('Precision')
plt.show()

# %%
plt.plot(th, precision[1:], 'b', label='Threshold-Precision curve')
plt.title('Precision for different threshold values')
plt.xlabel('Threshold')
plt.ylabel('Precision')
plt.show()

# %%
plt.plot(th, recall[1:], 'b', label='Threshold-Recall curve')
plt.title('Recall for different threshold values')
plt.xlabel('Reconstruction error')
plt.ylabel('Recall')
plt.show()

# %% [markdown]
# PREDICTION

# %%
threshold = 2.9

# %%
groups = error_df.groupby('true_class')
fig, ax = plt.subplots()

for name, group in groups:
    ax.plot(group.index, group.reconstruction_error, marker='o', ms=3.5, linestyle='',
            label= "Fraud" if name == 1 else "Normal")
ax.hlines(threshold, ax.get_xlim()[0], ax.get_xlim()[1], colors="r", zorder=100, label='Threshold')
ax.legend()
plt.title("Reconstruction error for different classes")
plt.ylabel("Reconstruction error")
plt.xlabel("Data point index")
plt.show();

# %%
y_pred = [1 if e > threshold else 0 for e in error_df.reconstruction_error.values]
conf_matrix = confusion_matrix(error_df.true_class, y_pred)

plt.figure(figsize=(12, 12))
sns.heatmap(conf_matrix, xticklabels=LABELS, yticklabels=LABELS, annot=True, fmt="d");
plt.title("Confusion matrix")
plt.ylabel('True class')
plt.xlabel('Predicted class')
plt.show()

# %% [markdown]
# Conclusion
# We've created a very simple Deep Autoencoder in Keras that can reconstruct what non fraudulent transactions looks like. Initially, I was a bit skeptical about whether or not this whole thing is gonna work out, bit it kinda did. Think about it, we gave a lot of one-class examples (normal transactions) to a model and it learned (somewhat) how to discriminate whether or not new examples belong to that same class. Isn't that cool? Our dataset was kind of magical, though. We really don't know what the original features look like.
#
# Keras gave us very clean and easy to use API to build a non-trivial Deep Autoencoder. You can search for TensorFlow implementations and see for yourself how much boilerplate you need in order to train one. Can you apply a similar model to a different problem?
